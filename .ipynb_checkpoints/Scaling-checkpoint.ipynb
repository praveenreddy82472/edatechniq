# %% [markdown]
# ### StandardScaler:
#     This method scales the data so that it has a mean of 0 and a standard deviation of 1.
#     It's suitable for data that is normally distributed and doesn't have outliers.
#
# ### MinMaxScaler:
#     This method scales the data to a fixed range, usually between 0 and 1.
#     It's sensitive to outliers and preserves the shape of the original distribution.
#
# ### RobustScaler:
#     This method scales the data using statistics that are robust to outliers, such as the median and interquartile range.
#     It's suitable for data with outliers or skewed distributions.
#
# ### MaxAbsScaler:
#     This method scales each feature to the absolute maximum value of that feature.
#     It's useful for data that is already centered at zero or sparse data.
#
# ### PowerTransformer:
#     This method applies a power transformation to make the data more Gaussian-like.
#     It supports both the Box-Cox and Yeo-Johnson transformations.
#
# ### QuantileTransformer:
#     This method transforms the features to follow a uniform or a normal distribution.
#     It's useful for data with non-linear distributions or when the relationships between features and target variables are non-linear.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, MaxAbsScaler, PowerTransformer, QuantileTransformer
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
X.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
plt.plot(X)

# %%
sns.scatterplot(X)
# Out:
# <Axes: >

# %%
# Method 1: StandardScaler
scaler1 = StandardScaler()
X_standard_scaled = scaler1.fit_transform(X)

# Method 2: MinMaxScaler
scaler2 = MinMaxScaler()
X_minmax_scaled = scaler2.fit_transform(X)

# Method 3: RobustScaler
scaler3 = RobustScaler()
X_robust_scaled = scaler3.fit_transform(X)

# Method 4: MaxAbsScaler
scaler4 = MaxAbsScaler()
X_maxabs_scaled = scaler4.fit_transform(X)

# Method 5: PowerTransformer
scaler5 = PowerTransformer()
X_power_scaled = scaler5.fit_transform(X)

# Method 6: QuantileTransformer
scaler6 = QuantileTransformer()
X_quantile_scaled = scaler6.fit_transform(X)

# %%
# Output the scaled data
print("StandardScaler:")
print(X_standard_scaled)
# Out:
# StandardScaler:
# [[-9.00681170e-01  1.01900435e+00 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00 -1.31979479e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.38535265e+00  3.28414053e-01 -1.39706395e+00 -1.31544430e+00]
#  [-1.50652052e+00  9.82172869e-02 -1.28338910e+00 -1.31544430e+00]
#  [-1.02184904e+00  1.24920112e+00 -1.34022653e+00 -1.31544430e+00]
#  [-5.37177559e-01  1.93979142e+00 -1.16971425e+00 -1.05217993e+00]
#  [-1.50652052e+00  7.88807586e-01 -1.34022653e+00 -1.18381211e+00]
#  [-1.02184904e+00  7.88807586e-01 -1.28338910e+00 -1.31544430e+00]
#  [-1.74885626e+00 -3.62176246e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00  9.82172869e-02 -1.28338910e+00 -1.44707648e+00]
#  [-5.37177559e-01  1.47939788e+00 -1.28338910e+00 -1.31544430e+00]
#  [-1.26418478e+00  7.88807586e-01 -1.22655167e+00 -1.31544430e+00]
#  [-1.26418478e+00 -1.31979479e-01 -1.34022653e+00 -1.44707648e+00]
#  [-1.87002413e+00 -1.31979479e-01 -1.51073881e+00 -1.44707648e+00]
# ...

# %%
print("\nMinMaxScaler:")
print(X_minmax_scaled)
# Out:
# MinMaxScaler:
# [[0.22222222 0.625      0.06779661 0.04166667]
#  [0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.11111111 0.5        0.05084746 0.04166667]
#  [0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.02777778 0.375      0.06779661 0.04166667]
#  [0.16666667 0.45833333 0.08474576 0.        ]
#  [0.30555556 0.70833333 0.08474576 0.04166667]
#  [0.13888889 0.58333333 0.10169492 0.04166667]
#  [0.13888889 0.41666667 0.06779661 0.        ]
#  [0.         0.41666667 0.01694915 0.        ]
#  [0.41666667 0.83333333 0.03389831 0.04166667]
#  [0.38888889 1.         0.08474576 0.125     ]
#  [0.30555556 0.79166667 0.05084746 0.125     ]
#  [0.22222222 0.625      0.06779661 0.08333333]
#  [0.38888889 0.75       0.11864407 0.08333333]
#  [0.22222222 0.75       0.08474576 0.08333333]
# ...

# %%
print("\nRobustScaler:")
print(X_robust_scaled)
# Out:
# RobustScaler:
# [[-0.53846154  1.         -0.84285714 -0.73333333]
#  [-0.69230769  0.         -0.84285714 -0.73333333]
#  [-0.84615385  0.4        -0.87142857 -0.73333333]
#  [-0.92307692  0.2        -0.81428571 -0.73333333]
#  [-0.61538462  1.2        -0.84285714 -0.73333333]
#  [-0.30769231  1.8        -0.75714286 -0.6       ]
#  [-0.92307692  0.8        -0.84285714 -0.66666667]
#  [-0.61538462  0.8        -0.81428571 -0.73333333]
#  [-1.07692308 -0.2        -0.84285714 -0.73333333]
#  [-0.69230769  0.2        -0.81428571 -0.8       ]
#  [-0.30769231  1.4        -0.81428571 -0.73333333]
#  [-0.76923077  0.8        -0.78571429 -0.73333333]
#  [-0.76923077  0.         -0.84285714 -0.8       ]
#  [-1.15384615  0.         -0.92857143 -0.8       ]
#  [ 0.          2.         -0.9        -0.73333333]
#  [-0.07692308  2.8        -0.81428571 -0.6       ]
#  [-0.30769231  1.8        -0.87142857 -0.6       ]
#  [-0.53846154  1.         -0.84285714 -0.66666667]
# ...

# %%
print(X_maxabs_scaled)
# Out:
# [[0.64556962 0.79545455 0.20289855 0.08      ]
#  [0.62025316 0.68181818 0.20289855 0.08      ]
#  [0.59493671 0.72727273 0.1884058  0.08      ]
#  [0.58227848 0.70454545 0.2173913  0.08      ]
#  [0.63291139 0.81818182 0.20289855 0.08      